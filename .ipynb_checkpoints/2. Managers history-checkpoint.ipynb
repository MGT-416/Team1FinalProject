# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Managers-clubs" data-toc-modified-id="Managers-clubs-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Managers clubs</a></span></li><li><span><a href="#Build-Network" data-toc-modified-id="Build-Network-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Build Network</a></span></li><li><span><a href="#Create-Network" data-toc-modified-id="Create-Network-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Create Network</a></span></li></ul></div>

# %%
# Beautiful Soup for web scrapping data
from bs4 import BeautifulSoup
import requests

# Pandas to reimport csv data
import pandas as pd

#NetworkX
import networkx as nx

# %%
def log_progress(sequence, every=None, size=None, name='Items', delete=False):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )
        if delete:
            box.close()

# %% [markdown]
# # Managers clubs

# %%
df = pd.read_csv("data/data.csv", index_col=0)
df.sample(5)
# Out:
#               Player Name                                Player Link  \
# 30282    nicolae-calancea     /nicolae-calancea/profil/spieler/44264
# 44357    dominik-hofbauer     /dominik-hofbauer/profil/spieler/49718
# 37565  francesco-di-paola  /francesco-di-paola/profil/spieler/409657
# 362      ingvar-thor-kale    /ingvar-thor-kale/profil/spieler/110175
# 7971         adam-dugdale         /adam-dugdale/profil/spieler/46460
#
#                                     Player position        From club  \
# 30282            Keeper                                 FC Voluntari
# 44357  Central Midfield                                   SCR Altach
# 37565    Centre-Forward                                      Foligno
# 362              Keeper                                     Víkingur
# 7971        Centre-Back                              Tranmere Rovers
#
#             To club        From competition         To competition  \
# 30282  CS U Craiova  Liga 1 - Abstiegsrunde  Liga 1 - Meisterrunde
# 44357   Arka Gdynia              Bundesliga            Ekstraklasa
# 37565     Viareggio      Serie D - Girone G     Serie D - Girone E
# 362           Valur              Pepsideild             Pepsideild
# 7971   Morecambe FC     Conference National             League Two
#
#              From manager                         From manager link  \
# 30282        Florin Marin         /florin-marin/profil/trainer/4789
# 44357        Damir Canadi         /damir-canadi/profil/trainer/4918
# 37565  Tommaso Guazzolini  /tommaso-guazzolini/profil/trainer/46761
# 362     Ólafur Thórdarson   /olafur-thordarson/profil/trainer/13998
# 7971          Gary Brabin          /gary-brabin/profil/trainer/8277
#
#                To manager                          To manager link  \
# 30282   Gheorghe Multescu   /gheorghe-multescu/profil/trainer/5429
# 44357   Grzegorz Nicinski  /grzegorz-nicinski/profil/trainer/24890
# 37565          Marco Masi         /marco-masi/profil/trainer/10065
# 362    Ólafur Jóhannesson  /olafur-johannesson/profil/trainer/1490
# 7971          Jim Bentley        /jim-bentley/profil/trainer/15236
#
#       Market value            Fee                          Age  \
# 30282    250 Th. €  Free transfer  29 years 10 months 02 days
# 44357    600 Th. €  Free transfer  25 years 11 months 26 days
# 37565    100 Th. €  Free transfer  31 years 09 months 20 days
# 362      100 Th. €  Free transfer            31 years 24 days
# 7971      50 Th. €  Free transfer  27 years 09 months 19 days
#
#       From manager agent To manager agent                   Player Agent
# 30282                NaN              NaN                            NaN
# 44357      Alliance ...               NaN           Polish Sports Group
# 37565                NaN              NaN                            NaN
# 362                  NaN              NaN                            NaN
# 7971                 NaN              NaN  FullNinety Sports Management

# %%
manager_from = list(set(df['From manager link']))
manager_to = list(set(df['To manager link']))
managers = list(set(manager_from + manager_to))
managers[:4]
# Out:
# ['/thierry-froger/profil/trainer/1536',
#  '/pedro-munitis/profil/trainer/39308',
#  '/roy-teubel/profil/trainer/42115',
#  '/edis-mulalic/profil/trainer/42658']

# %%
data = []

headers = {'User-Agent': 'Mozilla/5.00'}
base_url = "https://www.transfermarkt.com"

for manager_url in log_progress(managers, every=5):

    url = base_url + manager_url
    r  = requests.get(url, headers=headers)
    manager_data_page = BeautifulSoup(r.text, 'html.parser')

    manager_table = manager_data_page.find("div", {"class":"responsive-table"})
    for mt in manager_table.find('tbody').find_all('tr'):
        if 'class="extrarow bg_blau_20 rechts"' in str(mt):        
            break
        if "Manager" in str(mt):
            club = mt.findAll('a')[1].text
            data.append([manager_url, club])

# %%
df_2 = pd.DataFrame(data, columns=["Manager", "Club"])
df_2.Manager = df_2.Manager.apply(lambda x: x.split('/')[1])

# %%
df_2
# Out:
#                   Manager              Club
# 0          thierry-froger        TP Mazembe
# 1          thierry-froger        US Créteil
# 2          thierry-froger         OC Vannes
# 3          thierry-froger   Nîmes Olympique
# 4          thierry-froger              Togo
# 5          thierry-froger             Reims
# 6          thierry-froger       FC Gueugnon
# 7          thierry-froger    LB Châteauroux
# 8          thierry-froger        LOSC Lille
# 9          thierry-froger     Le Mans UC 72
# 10          pedro-munitis      Ponferradina
# 11          pedro-munitis            Racing
# 12             roy-teubel    VfL Hohenstein
# 13           edis-mulalic    Mladost Kakanj
# 14           edis-mulalic     FK Decic Tuzi
# 15           edis-mulalic       Zeljeznicar
# 16         filipe-gouveia           Covilhã
# 17         filipe-gouveia           Coimbra
# 18         filipe-gouveia       Santa Clara
# 19         filipe-gouveia        Salgueiros
# 20          mario-petrone           Catania
# 21          mario-petrone            Ascoli
# 22          mario-petrone           Bassano
# 23          mario-petrone        San Marino
# 24          mario-petrone           Sanluri
# 25          mario-petrone        San Marino
# 26          mario-petrone         Lumezzane
# 27          mario-petrone           Nuorese
# 28          mario-petrone          Msida SJ
# 29          mario-petrone            Tempio
# ...                   ...               ...
# 25672       georgi-ivanov      Lok. Plovdiv
# 25673       georgi-ivanov      Levski Sofia
# 25674       georgi-ivanov      Levski Sofia
# 25675    christoph-muller   SC Paderborn II
# 25676    anatoli-chantsev           Karpaty
# 25677    anatoli-chantsev       Metalurh Z.
# 25678   henri-kaasalainen      FC Honka U19
# 25679    kazimierz-moskal    Pogon Szczecin
# 25680    kazimierz-moskal      Wisla Kraków
# 25681    kazimierz-moskal      GKS Katowice
# 25682    kazimierz-moskal         Termalica
# 25683  harm-van-veldhoven      KVC Westerlo
# 25684  harm-van-veldhoven     Delhi Dynamos
# 25685  harm-van-veldhoven       KV Mechelen
# 25686  harm-van-veldhoven           Roda JC
# 25687  harm-van-veldhoven  Germinal Beersch
# 25688  harm-van-veldhoven     Cercle Brugge
# 25689  harm-van-veldhoven     KFC Strombeek
# 25690  harm-van-veldhoven         Lommel SK
# 25691         johan-wilny   Djurgardens U19
# 25692       mohamed-kouki    Stade Tunisien
# 25693       mohamed-kouki       ES Metlaoui
# 25694       mohamed-kouki          AS Gabès
# 25695       mohamed-kouki            O.Beja
# 25696       mohamed-kouki       Al Merreikh
# 25697       mohamed-kouki    Al-Ahly Shendi
# 25698       mohamed-kouki         EGS Gafsa
# 25699       mohamed-kouki      AS Kasserine
# 25700       mohamed-kouki            O.Beja
# 25701      bobi-stojkoski        Makedonija
#
# [25702 rows x 2 columns]

# %% [markdown]
# # Build Network

# %%
G = nx.Graph()

# %%
for a in df_2.groupby('Club'):
    managers = a[1].Manager
    if len(managers)>1:
        for m1 in managers:
            for m2 in managers:
                if m1!=m2:
                    G.add_edge(m1,m2, club=a[0])

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 4976
# Number of edges: 47204
# Average degree:  18.9727

# %%
nx.write_gml(G, "networks/managers.gml")
